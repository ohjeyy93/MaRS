# %%
import pandas as pd
import csv
import numpy

read_file = pd.read_csv("Example_haplotype_data_sheet.txt")
read_file.to_csv("Example_haplotype_data_sheet.csv")

import csv
datafile = open("Example_haplotype_data_sheet.csv")
datareader = csv.reader(datafile, delimiter=';')
data = []
for row in datareader:
    data.append(row)    
#print (data)

#reader = csv.reader(open("Example_haplotype_data_sheet.csv", "rt"), delimiter=",")
#x = list(reader)
#result = numpy.array(x)
#print(result)

#data = list(csv.reader(open("Example_haplotype_data_sheet.csv")))
#print(data)

f = open("Example_haplotype_data_sheet.txt", "r")
count=0
ids=[]
for line in f:
    #count=0
    #for word in line.split():
    #    count+=1
    #    if count==1: 
    count+=1
    if count>1:
        ids+=[line.split()[0]]

locinames = ["CDC1","CDC2","CDC3","CDC4","X378_PART_A","X378_PART_B","X378_PART_C", 
             "X360i2_PART_A","X360i2_PART_B","X360i2_PART_C","X360i2.PART_D", "Junction","MSR_Left","MSR_Right"]

locinames_base = ["CDC1","CDC2","CDC3","CDC4","X378","X360","Junction","MSR"]

ploidy = [2,2,2,2,2,2,2,2,2,2,2,1,1,1]

nids = len(ids)
nloci = len(locinames)

count=0
#print("test")
#print(ids)
#f = open("Example_haplotype_data_sheet.txt", "r")
#for line in f: 
#    count+=1
#    #print(count)
#    if count>2:
#        for word in line:
#            #print(word)
#            if word=="\t":
#                print("True")
#            elif word=="X":
#                print("False")

countList=0
wholeList=[]
for list in data:
    print(list)
    tempList=[]
    countList+=1
    countString=0
    for x in "".join(list):
        #print(x)
        if countList>1:
            if x=="X":tempList+=["False"]
            elif x=="\t":
                countString+=1
                if countString>1:
                    tempList+=["True"]
    if tempList!=[]:
        wholeList+=[tempList]
print(wholeList)
# Out:
# [',Seq_ID\tCDC1_Hap_1\tCDC1_Hap_2\tCDC1_Hap_3\tCDC1_Hap_4\tCDC2_Hap_1\tCDC2_Hap_2\tCDC2_Hap_3\tCDC2_Hap_4\tCDC3_Hap_1\tCDC3_Hap_2\tCDC3_Hap_3\tCDC3_Hap_4\tCDC4_Hap_1\tCDC4_Hap_2\tCDC4_Hap_3\tCDC4_Hap_4\t378_PART_A_Hap_1\t378_PART_A_Hap_2\t378_PART_A_Hap_3\t378_PART_A_Hap_4\t378_PART_A_Hap_5\t378_PART_A_Hap_6\t378_PART_A_Hap_7\t378_PART_A_Hap_8\t378_PART_A_Hap_9\t378_PART_A_Hap_10\t378_PART_B_Hap_1\t378_PART_B_Hap_2\t378_PART_B_Hap_3\t378_PART_B_Hap_4\t378_PART_B_Hap_5\t378_PART_B_Hap_6\t378_PART_C_Hap_1\t378_PART_C_Hap_2\t378_PART_C_Hap_3\t378_PART_C_Hap_4\t378_PART_C_Hap_5\t378_PART_C_Hap_6\t378_PART_C_Hap_7\t378_PART_C_Hap_8\t360i2_PART_A_Hap_1\t360i2_PART_A_Hap_2\t360i2_PART_A_Hap_3\t360i2_PART_A_Hap_4\t360i2_PART_A_Hap_5\t360i2_PART_A_Hap_6\t360i2_PART_B_Hap_1\t360i2_PART_B_Hap_2\t360i2_PART_B_Hap_3\t360i2_PART_B_Hap_4\t360i2_PART_B_Hap_5\t360i2_PART_B_Hap_6\t360i2_PART_B_Hap_7\t360i2_PART_B_Hap_8\t360i2_PART_B_Hap_9\t360i2_PART_B_Hap_10\t360i2_PART_C_Hap_1\t360i2_PART_C_Hap_2\t360i2_PART_C_Hap_3\t360i2_PART_C_Hap_4\t360i2_PART_C_Hap_5\t360i2_PART_C_Hap_6\t360i2_PART_C_Hap_7\t360i2_PART_C_Hap_8\t360i2_PART_D_Hap_1\t360i2_PART_D_Hap_2\t360i2_PART_D_Hap_3\t360i2_PART_D_Hap_4\t360i2_PART_D_Hap_5\t360i2_PART_D_Hap_6\tJunction_Hap_1\tJunction_Hap_2\tJunction_Hap_3\tJunction_Hap_4\tJunction_Hap_5\tJunction_Hap_6\tJunction_Hap_7\tJunction_Hap_8\tJunction_Hap_9\tJunction_Hap_10\tJunction_Hap_11\tJunction_Hap_12\tJunction_Hap_13\tJunction_Hap_14\tJunction_Hap_15\tJunction_Hap_16\tJunction_Hap_17\tJunction_Hap_18\tJunction_Hap_19\tJunction_Hap_20\tJunction_Hap_21\tJunction_Hap_22\tJunction_Hap_23\tJunction_Hap_24\tMSR_Left_Hap_1\tMSR_Left_Hap_2\tMSR_Left_Hap_3\tMSR_Left_Hap_4\tMSR_Left_Hap_5\tMSR_Left_Hap_6\tMSR_Left_Hap_7\tMSR_Left_Hap_8\tMSR_Right_Hap_1\tMSR_Right_Hap_2\tMSR_Right_Hap_3\tMSR_Right_Hap_4\tMSR_Right_Hap_5\tMSR_Right_Hap_6\tMSR_Right_Hap_7\tMSR_Right_Hap_8']
# ['0,C_CA003_18\tX\t\t\t\tX\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['1,C_IA004_18\t\t\t\t\t\tX\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['2,C_IA005_18\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['3,C_IA006_18\t\t\t\t\tX\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['4,C_IA007_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['5,C_IA008_18\t\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['6,C_IA010_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['7,C_IA011_18\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['8,C_IA009_18\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['9,C_IA014_18\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t']
# ['10,C_IA013_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['11,C_IA012_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['12,C_IA015_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['13,C_IA016_18\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['14,C_IA018_18\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['15,C_IA017_18\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\tX\tX\tX\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['16,C_IA019_18\t\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['17,C_IA020_18\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['18,C_IA021_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['19,C_IA022_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['20,C_IA023_18\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['21,C_IA055_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['22,C_IA027_18\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['23,C_IA025_18\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['24,C_IA026_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['25,C_IA028_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['26,C_IA057_18\t\tX\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['27,C_IA024_18\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['28,C_IA029_18\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['29,C_IA058_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['30,C_IA059_18\tX\t\t\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['31,C_IA050_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['32,C_IA051_18\tX\t\t\t\tX\t\t\t\tX\t\t\t\tX\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['33,C_IA052_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['34,C_IA053_18\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['35,C_IA054_18\t\tX\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['36,C_IA040_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['37,C_IA041_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['38,C_IA042_18\tX\t\t\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['39,C_IA043_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['40,C_IA044_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['41,C_IA030_18\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['42,C_IA031_18\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['43,C_IA033_18\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['44,C_IA034_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['45,C_IA035_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['46,C_IA036_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['47,C_IA037_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['48,C_IA038_18\t\tX\t\t\t\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['49,C_IA039_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['50,C_IA045_18\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['51,C_IA046_18\t\tX\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['52,C_IA047_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['53,C_IA048_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['54,C_IA063_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['55,C_IA049_18\t\tX\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['56,C_IA061_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['57,C_IA071_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['58,C_IA068_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['59,C_IA069_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['60,C_IA070_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['61,C_IA078_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['62,C_IA065_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['63,C_IA066_18\t\tX\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['64,C_IA076_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['65,C_IA077_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['66,C_IA075_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['67,C_IA062_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['68,C_IA081_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['69,C_IA082_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['70,C_IA084_18\t\tX\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['71,C_IA083_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['72,C_IA072_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['73,C_IA074_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['74,C_IA073_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['75,C_IA067_18\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['76,C_IA080_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['77,C_IA086_18\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['78,C_IA064_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['79,C_IA079_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['80,C_IA085_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['81,C_IA087_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['82,C_IA092_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['83,C_IA091_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['84,C_IA089_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['85,C_IA090_18\t\tX\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t']
# ['86,C_IA060_18\t\t\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['87,C_IA096_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['88,C_IA088_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['89,C_IA101_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['90,C_IA099_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['91,C_IA122_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['92,C_IA120_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['93,C_IA121_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# ['94,C_IA123_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['95,C_IA118_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['96,C_IA124_18\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t']
# ['97,C_IA104_18\t\tX\t\t\tX\t\t\t\tX\t\t\t\t\tX\t\t\t\t\t\tX\t\t\tX\t\t\t\t\tX\t\t\t\t\tX\tX\tX\t\t\t\t\t\tX\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\tX\tX\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t\tX\t\t\t\t\t\t\t']
# [['False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True'], ['True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True'], ['True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True'], ['True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'Fa ...
